# %%
# IMPORTAÇÕES E CONFIGURAÇÃO DO AGENTE DQN
import random
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque

class QNetwork(nn.Module):
    """Rede Neural profunda para aproximar a função Q."""
    def __init__(self, state_dim, action_dim):
        super(QNetwork, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, action_dim)
        )

    def forward(self, x):
        return self.fc(x)

class DQNAgent:
    def __init__(self, state_dim, action_dim, lr=1e-3, gamma=0.99,
                 epsilon_start=1.0, epsilon_min=0.01, epsilon_decay=0.995, buffer_size=10000):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay

        self.policy_net = QNetwork(state_dim, action_dim)
        self.target_net = QNetwork(state_dim, action_dim)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
        self.memory = deque(maxlen=buffer_size)

    def select_action(self, state):
        if random.random() < self.epsilon:
            return random.randint(0, self.action_dim - 1)
        state_t = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.policy_net(state_t)
        return torch.argmax(q_values).item()

    def store_transition(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def update(self, batch_size):
        if len(self.memory) < batch_size:
            return None

        batch = random.sample(self.memory, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states_t = torch.FloatTensor(states)
        actions_t = torch.LongTensor(actions).unsqueeze(1)
        rewards_t = torch.FloatTensor(rewards)
        next_states_t = torch.FloatTensor(next_states)
        dones_t = torch.FloatTensor(dones)

        current_q = self.policy_net(states_t).gather(1, actions_t).squeeze(1)

        with torch.no_grad():
            max_next_q = self.target_net(next_states_t).max(1)[0]
            target_q = rewards_t + (1 - dones_t) * self.gamma * max_next_q

        loss = nn.MSELoss()(current_q, target_q)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        return loss.item()

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# %%
# TREINAMENTO

STATE_DIM = 5
ACTION_DIM = 5

MAX_FILA = 30
MAX_TEMPO = 60

def normalizar_estado(state):
    fila_NS, fila_LO, tempo_V, fase_atual, tempo_desde_troca = state
    return np.array([
        fila_NS / MAX_FILA,
        fila_LO / MAX_FILA,
        tempo_V / MAX_TEMPO,
        float(fase_atual),
        min(1.0, tempo_desde_troca / 20.0)
    ], dtype=np.float32)

def simulated_step(state, action, step_count):
    fila_NS, fila_LO, tempo_V, fase_atual, tempo_desde_troca = state

    if action == 1 and fase_atual != 0: fase_atual = 0; tempo_desde_troca = 0
    elif action == 2 and fase_atual != 1: fase_atual = 1; tempo_desde_troca = 0
    elif action == 3: tempo_V = min(MAX_TEMPO, tempo_V + 5)
    elif action == 4: tempo_V = max(10, tempo_V - 5)
    else: tempo_desde_troca += 1

    # Modelagem do cenário
    if step_count <= 20:
        # Madrugada: Raramente chega carro
        chegada_NS = 1 if np.random.random() < 0.2 else 0
        chegada_LO = 1 if np.random.random() < 0.1 else 0

    elif 20 < step_count <= 50:
        # Pico da Manhã: Forte fluxo no sentido Norte-Sul
        chegada_NS = np.random.randint(1, 4) # Chega muito carro
        chegada_LO = np.random.randint(0, 2) # Fluxo calmo

    elif 50 < step_count <= 80:
        # Horário Comercial: Fluxo constante e moderado em ambos os lados
        chegada_NS = np.random.randint(0, 2)
        chegada_LO = np.random.randint(0, 2)

    else:
        # Pico da Tarde: Retorno para casa, forte fluxo em Leste-Oeste
        chegada_NS = np.random.randint(0, 2)
        chegada_LO = np.random.randint(1, 4) # Chega muito carro

    # Capacidade de escoamento
    vazo_NS = 3 if fase_atual == 0 else 0
    vazo_LO = 3 if fase_atual == 1 else 0

    fila_NS = max(0, min(MAX_FILA, fila_NS + chegada_NS - vazo_NS))
    fila_LO = max(0, min(MAX_FILA, fila_LO + chegada_LO - vazo_LO))

    # Cálculo da recompensa escalada
    reward = -(fila_NS + fila_LO) / (MAX_FILA * 2)

    # Penalidades
    if action in [1, 2] and tempo_desde_troca < 5:
        reward -= 0.02
    if fila_NS > 20 or fila_LO > 20:
        reward -= 0.05

    next_state = [fila_NS, fila_LO, tempo_V, fase_atual, tempo_desde_troca]
    return np.array(next_state), reward, False

def treinar_agente():
    agent = DQNAgent(state_dim=5, action_dim=5, lr=1e-4, epsilon_decay=0.992)

    episodes = 1000
    batch_size = 64
    target_update_freq = 20

    reward_history = []
    loss_history = []
    best_avg_reward = -float('inf')
    patience, patience_counter = 40, 0

    for episode in range(1, episodes + 1):
        raw_state = np.array([12, 7, 25, 0, 10])
        ep_reward = 0
        ep_losses = []

        for step in range(100):
            state_norm = normalizar_estado(raw_state)
            action = agent.select_action(state_norm)

            next_raw_state, reward, done = simulated_step(raw_state, action, step)
            next_state_norm = normalizar_estado(next_raw_state)

            agent.store_transition(state_norm, action, reward, next_state_norm, done)

            if len(agent.memory) >= batch_size:
                batch = random.sample(agent.memory, batch_size)
                states_b, actions_b, rewards_b, next_states_b, dones_b = zip(*batch)

                states_t = torch.FloatTensor(np.array(states_b))
                actions_t = torch.LongTensor(actions_b).unsqueeze(1)
                rewards_t = torch.FloatTensor(rewards_b)
                next_states_t = torch.FloatTensor(np.array(next_states_b))
                dones_t = torch.FloatTensor(dones_b)

                current_q = agent.policy_net(states_t).gather(1, actions_t).squeeze(1)
                with torch.no_grad():
                    max_next_q = agent.target_net(next_states_t).max(1)[0]
                    target_q = rewards_t + (1 - dones_t) * agent.gamma * max_next_q

                loss = nn.MSELoss()(current_q, target_q)
                agent.optimizer.zero_grad()
                loss.backward()
                agent.optimizer.step()
                ep_losses.append(loss.item())

            raw_state = next_raw_state
            ep_reward += reward

        if agent.epsilon > agent.epsilon_min:
            agent.epsilon *= agent.epsilon_decay

        if episode % target_update_freq == 0:
            agent.update_target_network()

        reward_history.append(ep_reward)
        loss_history.append(np.mean(ep_losses) if ep_losses else 0)

        running_reward = np.mean(reward_history[-10:])
        print(f"Episódio {episode:03d}/{episodes} | Recompensa: {ep_reward:.2f} | Média Móvel (10 ep): {running_reward:.2f} | Epsilon: {agent.epsilon:.2f}")

        if running_reward > best_avg_reward:
            best_avg_reward = running_reward
            patience_counter = 0
            torch.save(agent.policy_net.state_dict(), "best_traffic_dqn.pt")
            print("=> [Sinal Verde] Modelo Excelente Guardado!")
        else:
            if episode > 60:
                patience_counter += 1

        if patience_counter >= patience:
            print(f"\n[Early Stopping] Modelo Perfeito Convergido no episódio {episode}.")
            break

    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(reward_history, alpha=0.3, color="b", label="Recompensa Real")
    sma = np.convolve(reward_history, np.ones(10)/10, mode='valid')
    plt.plot(range(9, len(reward_history)), sma, color="darkblue", linewidth=2, label="Tendência (Média Móvel)")
    plt.title("Curva de Aprendizado (Alvo Próximo a Zero)")
    plt.xlabel("Episódios"); plt.ylabel("Recompensa Acumulada"); plt.grid(True); plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(loss_history, color="purple")
    plt.title("Evolução do Erro da Rede (Loss)")
    plt.xlabel("Episódios"); plt.ylabel("Valor do Erro"); plt.grid(True)

    plt.tight_layout()
    plt.savefig("grafico_convergencia_perfeito.png", dpi=300)
    plt.show()

import random
treinar_agente()
# Out:
# Episódio 001/1000 | Recompensa: -28.22 | Média Móvel (10 ep): -28.22 | Epsilon: 0.99
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 002/1000 | Recompensa: -18.92 | Média Móvel (10 ep): -23.57 | Epsilon: 0.98
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 003/1000 | Recompensa: -34.27 | Média Móvel (10 ep): -27.13 | Epsilon: 0.98
# Episódio 004/1000 | Recompensa: -15.19 | Média Móvel (10 ep): -24.15 | Epsilon: 0.97
# Episódio 005/1000 | Recompensa: -15.15 | Média Móvel (10 ep): -22.35 | Epsilon: 0.96
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 006/1000 | Recompensa: -14.98 | Média Móvel (10 ep): -21.12 | Epsilon: 0.95
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 007/1000 | Recompensa: -28.56 | Média Móvel (10 ep): -22.18 | Epsilon: 0.95
# Episódio 008/1000 | Recompensa: -22.54 | Média Móvel (10 ep): -22.23 | Epsilon: 0.94
# Episódio 009/1000 | Recompensa: -17.63 | Média Móvel (10 ep): -21.72 | Epsilon: 0.93
# Episódio 010/1000 | Recompensa: -17.85 | Média Móvel (10 ep): -21.33 | Epsilon: 0.92
# Episódio 011/1000 | Recompensa: -15.45 | Média Móvel (10 ep): -20.05 | Epsilon: 0.92
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 012/1000 | Recompensa: -15.04 | Média Móvel (10 ep): -19.67 | Epsilon: 0.91
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 013/1000 | Recompensa: -13.44 | Média Móvel (10 ep): -17.58 | Epsilon: 0.90
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 014/1000 | Recompensa: -14.29 | Média Móvel (10 ep): -17.49 | Epsilon: 0.89
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 015/1000 | Recompensa: -11.21 | Média Móvel (10 ep): -17.10 | Epsilon: 0.89
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 016/1000 | Recompensa: -15.40 | Média Móvel (10 ep): -17.14 | Epsilon: 0.88
# Episódio 017/1000 | Recompensa: -10.63 | Média Móvel (10 ep): -15.35 | Epsilon: 0.87
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 018/1000 | Recompensa: -24.45 | Média Móvel (10 ep): -15.54 | Epsilon: 0.87
# Episódio 019/1000 | Recompensa: -11.40 | Média Móvel (10 ep): -14.92 | Epsilon: 0.86
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 020/1000 | Recompensa: -19.42 | Média Móvel (10 ep): -15.07 | Epsilon: 0.85
# Episódio 021/1000 | Recompensa: -6.98 | Média Móvel (10 ep): -14.23 | Epsilon: 0.84
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 022/1000 | Recompensa: -8.70 | Média Móvel (10 ep): -13.59 | Epsilon: 0.84
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 023/1000 | Recompensa: -10.91 | Média Móvel (10 ep): -13.34 | Epsilon: 0.83
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 024/1000 | Recompensa: -6.49 | Média Móvel (10 ep): -12.56 | Epsilon: 0.82
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 025/1000 | Recompensa: -6.27 | Média Móvel (10 ep): -12.07 | Epsilon: 0.82
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 026/1000 | Recompensa: -16.05 | Média Móvel (10 ep): -12.13 | Epsilon: 0.81
# Episódio 027/1000 | Recompensa: -15.98 | Média Móvel (10 ep): -12.67 | Epsilon: 0.81
# Episódio 028/1000 | Recompensa: -10.31 | Média Móvel (10 ep): -11.25 | Epsilon: 0.80
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 029/1000 | Recompensa: -12.95 | Média Móvel (10 ep): -11.41 | Epsilon: 0.79
# Episódio 030/1000 | Recompensa: -11.88 | Média Móvel (10 ep): -10.65 | Epsilon: 0.79
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 031/1000 | Recompensa: -10.97 | Média Móvel (10 ep): -11.05 | Epsilon: 0.78
# Episódio 032/1000 | Recompensa: -12.60 | Média Móvel (10 ep): -11.44 | Epsilon: 0.77
# Episódio 033/1000 | Recompensa: -7.50 | Média Móvel (10 ep): -11.10 | Epsilon: 0.77
# Episódio 034/1000 | Recompensa: -10.17 | Média Móvel (10 ep): -11.47 | Epsilon: 0.76
# Episódio 035/1000 | Recompensa: -7.40 | Média Móvel (10 ep): -11.58 | Epsilon: 0.75
# Episódio 036/1000 | Recompensa: -5.03 | Média Móvel (10 ep): -10.48 | Epsilon: 0.75
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 037/1000 | Recompensa: -9.44 | Média Móvel (10 ep): -9.82 | Epsilon: 0.74
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 038/1000 | Recompensa: -7.40 | Média Móvel (10 ep): -9.53 | Epsilon: 0.74
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 039/1000 | Recompensa: -7.36 | Média Móvel (10 ep): -8.97 | Epsilon: 0.73
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 040/1000 | Recompensa: -8.05 | Média Móvel (10 ep): -8.59 | Epsilon: 0.73
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 041/1000 | Recompensa: -5.85 | Média Móvel (10 ep): -8.08 | Epsilon: 0.72
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 042/1000 | Recompensa: -12.08 | Média Móvel (10 ep): -8.03 | Epsilon: 0.71
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 043/1000 | Recompensa: -12.58 | Média Móvel (10 ep): -8.53 | Epsilon: 0.71
# Episódio 044/1000 | Recompensa: -12.49 | Média Móvel (10 ep): -8.77 | Epsilon: 0.70
# Episódio 045/1000 | Recompensa: -8.12 | Média Móvel (10 ep): -8.84 | Epsilon: 0.70
# Episódio 046/1000 | Recompensa: -11.22 | Média Móvel (10 ep): -9.46 | Epsilon: 0.69
# Episódio 047/1000 | Recompensa: -6.04 | Média Móvel (10 ep): -9.12 | Epsilon: 0.69
# Episódio 048/1000 | Recompensa: -8.21 | Média Móvel (10 ep): -9.20 | Epsilon: 0.68
# Episódio 049/1000 | Recompensa: -6.41 | Média Móvel (10 ep): -9.11 | Epsilon: 0.67
# Episódio 050/1000 | Recompensa: -7.60 | Média Móvel (10 ep): -9.06 | Epsilon: 0.67
# Episódio 051/1000 | Recompensa: -7.98 | Média Móvel (10 ep): -9.27 | Epsilon: 0.66
# Episódio 052/1000 | Recompensa: -6.55 | Média Móvel (10 ep): -8.72 | Epsilon: 0.66
# Episódio 053/1000 | Recompensa: -5.71 | Média Móvel (10 ep): -8.03 | Epsilon: 0.65
# Episódio 054/1000 | Recompensa: -6.65 | Média Móvel (10 ep): -7.45 | Epsilon: 0.65
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 055/1000 | Recompensa: -5.22 | Média Móvel (10 ep): -7.16 | Epsilon: 0.64
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 056/1000 | Recompensa: -6.57 | Média Móvel (10 ep): -6.69 | Epsilon: 0.64
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 057/1000 | Recompensa: -8.26 | Média Móvel (10 ep): -6.92 | Epsilon: 0.63
# Episódio 058/1000 | Recompensa: -5.35 | Média Móvel (10 ep): -6.63 | Epsilon: 0.63
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 059/1000 | Recompensa: -5.27 | Média Móvel (10 ep): -6.52 | Epsilon: 0.62
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 060/1000 | Recompensa: -4.72 | Média Móvel (10 ep): -6.23 | Epsilon: 0.62
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 061/1000 | Recompensa: -8.35 | Média Móvel (10 ep): -6.26 | Epsilon: 0.61
# Episódio 062/1000 | Recompensa: -7.71 | Média Móvel (10 ep): -6.38 | Epsilon: 0.61
# Episódio 063/1000 | Recompensa: -6.51 | Média Móvel (10 ep): -6.46 | Epsilon: 0.60
# Episódio 064/1000 | Recompensa: -6.75 | Média Móvel (10 ep): -6.47 | Epsilon: 0.60
# Episódio 065/1000 | Recompensa: -5.75 | Média Móvel (10 ep): -6.52 | Epsilon: 0.59
# Episódio 066/1000 | Recompensa: -6.30 | Média Móvel (10 ep): -6.50 | Epsilon: 0.59
# Episódio 067/1000 | Recompensa: -5.91 | Média Móvel (10 ep): -6.26 | Epsilon: 0.58
# Episódio 068/1000 | Recompensa: -5.00 | Média Móvel (10 ep): -6.23 | Epsilon: 0.58
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 069/1000 | Recompensa: -5.30 | Média Móvel (10 ep): -6.23 | Epsilon: 0.57
# Episódio 070/1000 | Recompensa: -6.29 | Média Móvel (10 ep): -6.39 | Epsilon: 0.57
# Episódio 071/1000 | Recompensa: -4.85 | Média Móvel (10 ep): -6.04 | Epsilon: 0.57
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 072/1000 | Recompensa: -6.97 | Média Móvel (10 ep): -5.96 | Epsilon: 0.56
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 073/1000 | Recompensa: -4.27 | Média Móvel (10 ep): -5.74 | Epsilon: 0.56
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 074/1000 | Recompensa: -6.03 | Média Móvel (10 ep): -5.67 | Epsilon: 0.55
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 075/1000 | Recompensa: -4.88 | Média Móvel (10 ep): -5.58 | Epsilon: 0.55
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 076/1000 | Recompensa: -6.66 | Média Móvel (10 ep): -5.62 | Epsilon: 0.54
# Episódio 077/1000 | Recompensa: -5.71 | Média Móvel (10 ep): -5.60 | Epsilon: 0.54
# Episódio 078/1000 | Recompensa: -5.33 | Média Móvel (10 ep): -5.63 | Epsilon: 0.53
# Episódio 079/1000 | Recompensa: -7.32 | Média Móvel (10 ep): -5.83 | Epsilon: 0.53
# Episódio 080/1000 | Recompensa: -6.39 | Média Móvel (10 ep): -5.84 | Epsilon: 0.53
# Episódio 081/1000 | Recompensa: -6.08 | Média Móvel (10 ep): -5.96 | Epsilon: 0.52
# Episódio 082/1000 | Recompensa: -7.47 | Média Móvel (10 ep): -6.01 | Epsilon: 0.52
# Episódio 083/1000 | Recompensa: -4.95 | Média Móvel (10 ep): -6.08 | Epsilon: 0.51
# Episódio 084/1000 | Recompensa: -7.05 | Média Móvel (10 ep): -6.18 | Epsilon: 0.51
# Episódio 085/1000 | Recompensa: -6.57 | Média Móvel (10 ep): -6.35 | Epsilon: 0.51
# Episódio 086/1000 | Recompensa: -5.04 | Média Móvel (10 ep): -6.19 | Epsilon: 0.50
# Episódio 087/1000 | Recompensa: -5.48 | Média Móvel (10 ep): -6.17 | Epsilon: 0.50
# Episódio 088/1000 | Recompensa: -5.74 | Média Móvel (10 ep): -6.21 | Epsilon: 0.49
# Episódio 089/1000 | Recompensa: -4.78 | Média Móvel (10 ep): -5.95 | Epsilon: 0.49
# Episódio 090/1000 | Recompensa: -4.80 | Média Móvel (10 ep): -5.79 | Epsilon: 0.49
# Episódio 091/1000 | Recompensa: -5.46 | Média Móvel (10 ep): -5.73 | Epsilon: 0.48
# Episódio 092/1000 | Recompensa: -5.73 | Média Móvel (10 ep): -5.56 | Epsilon: 0.48
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 093/1000 | Recompensa: -6.01 | Média Móvel (10 ep): -5.67 | Epsilon: 0.47
# Episódio 094/1000 | Recompensa: -6.02 | Média Móvel (10 ep): -5.56 | Epsilon: 0.47
# Episódio 095/1000 | Recompensa: -7.23 | Média Móvel (10 ep): -5.63 | Epsilon: 0.47
# Episódio 096/1000 | Recompensa: -4.29 | Média Móvel (10 ep): -5.55 | Epsilon: 0.46
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 097/1000 | Recompensa: -6.16 | Média Móvel (10 ep): -5.62 | Epsilon: 0.46
# Episódio 098/1000 | Recompensa: -5.09 | Média Móvel (10 ep): -5.56 | Epsilon: 0.46
# Episódio 099/1000 | Recompensa: -6.61 | Média Móvel (10 ep): -5.74 | Epsilon: 0.45
# Episódio 100/1000 | Recompensa: -3.87 | Média Móvel (10 ep): -5.65 | Epsilon: 0.45
# Episódio 101/1000 | Recompensa: -5.51 | Média Móvel (10 ep): -5.65 | Epsilon: 0.44
# Episódio 102/1000 | Recompensa: -4.31 | Média Móvel (10 ep): -5.51 | Epsilon: 0.44
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 103/1000 | Recompensa: -4.98 | Média Móvel (10 ep): -5.41 | Epsilon: 0.44
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 104/1000 | Recompensa: -4.90 | Média Móvel (10 ep): -5.30 | Epsilon: 0.43
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 105/1000 | Recompensa: -4.91 | Média Móvel (10 ep): -5.06 | Epsilon: 0.43
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 106/1000 | Recompensa: -4.85 | Média Móvel (10 ep): -5.12 | Epsilon: 0.43
# Episódio 107/1000 | Recompensa: -5.95 | Média Móvel (10 ep): -5.10 | Epsilon: 0.42
# Episódio 108/1000 | Recompensa: -5.43 | Média Móvel (10 ep): -5.13 | Epsilon: 0.42
# Episódio 109/1000 | Recompensa: -3.96 | Média Móvel (10 ep): -4.87 | Epsilon: 0.42
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 110/1000 | Recompensa: -6.08 | Média Móvel (10 ep): -5.09 | Epsilon: 0.41
# Episódio 111/1000 | Recompensa: -7.35 | Média Móvel (10 ep): -5.27 | Epsilon: 0.41
# Episódio 112/1000 | Recompensa: -5.21 | Média Móvel (10 ep): -5.36 | Epsilon: 0.41
# Episódio 113/1000 | Recompensa: -5.17 | Média Móvel (10 ep): -5.38 | Epsilon: 0.40
# Episódio 114/1000 | Recompensa: -6.18 | Média Móvel (10 ep): -5.51 | Epsilon: 0.40
# Episódio 115/1000 | Recompensa: -4.49 | Média Móvel (10 ep): -5.47 | Epsilon: 0.40
# Episódio 116/1000 | Recompensa: -5.93 | Média Móvel (10 ep): -5.58 | Epsilon: 0.39
# Episódio 117/1000 | Recompensa: -3.86 | Média Móvel (10 ep): -5.37 | Epsilon: 0.39
# Episódio 118/1000 | Recompensa: -5.44 | Média Móvel (10 ep): -5.37 | Epsilon: 0.39
# Episódio 119/1000 | Recompensa: -4.59 | Média Móvel (10 ep): -5.43 | Epsilon: 0.38
# Episódio 120/1000 | Recompensa: -5.79 | Média Móvel (10 ep): -5.40 | Epsilon: 0.38
# Episódio 121/1000 | Recompensa: -5.07 | Média Móvel (10 ep): -5.17 | Epsilon: 0.38
# Episódio 122/1000 | Recompensa: -4.91 | Média Móvel (10 ep): -5.14 | Epsilon: 0.38
# Episódio 123/1000 | Recompensa: -8.05 | Média Móvel (10 ep): -5.43 | Epsilon: 0.37
# Episódio 124/1000 | Recompensa: -4.54 | Média Móvel (10 ep): -5.27 | Epsilon: 0.37
# Episódio 125/1000 | Recompensa: -5.23 | Média Móvel (10 ep): -5.34 | Epsilon: 0.37
# Episódio 126/1000 | Recompensa: -4.32 | Média Móvel (10 ep): -5.18 | Epsilon: 0.36
# Episódio 127/1000 | Recompensa: -3.93 | Média Móvel (10 ep): -5.19 | Epsilon: 0.36
# Episódio 128/1000 | Recompensa: -5.11 | Média Móvel (10 ep): -5.15 | Epsilon: 0.36
# Episódio 129/1000 | Recompensa: -4.98 | Média Móvel (10 ep): -5.19 | Epsilon: 0.35
# Episódio 130/1000 | Recompensa: -4.98 | Média Móvel (10 ep): -5.11 | Epsilon: 0.35
# Episódio 131/1000 | Recompensa: -4.83 | Média Móvel (10 ep): -5.09 | Epsilon: 0.35
# Episódio 132/1000 | Recompensa: -6.26 | Média Móvel (10 ep): -5.22 | Epsilon: 0.35
# Episódio 133/1000 | Recompensa: -3.46 | Média Móvel (10 ep): -4.76 | Epsilon: 0.34
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 134/1000 | Recompensa: -4.45 | Média Móvel (10 ep): -4.75 | Epsilon: 0.34
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 135/1000 | Recompensa: -6.56 | Média Móvel (10 ep): -4.89 | Epsilon: 0.34
# Episódio 136/1000 | Recompensa: -4.21 | Média Móvel (10 ep): -4.88 | Epsilon: 0.34
# Episódio 137/1000 | Recompensa: -4.82 | Média Móvel (10 ep): -4.97 | Epsilon: 0.33
# Episódio 138/1000 | Recompensa: -6.63 | Média Móvel (10 ep): -5.12 | Epsilon: 0.33
# Episódio 139/1000 | Recompensa: -3.47 | Média Móvel (10 ep): -4.97 | Epsilon: 0.33
# Episódio 140/1000 | Recompensa: -4.83 | Média Móvel (10 ep): -4.95 | Epsilon: 0.32
# Episódio 141/1000 | Recompensa: -5.50 | Média Móvel (10 ep): -5.02 | Epsilon: 0.32
# Episódio 142/1000 | Recompensa: -5.07 | Média Móvel (10 ep): -4.90 | Epsilon: 0.32
# Episódio 143/1000 | Recompensa: -3.89 | Média Móvel (10 ep): -4.94 | Epsilon: 0.32
# Episódio 144/1000 | Recompensa: -3.67 | Média Móvel (10 ep): -4.87 | Epsilon: 0.31
# Episódio 145/1000 | Recompensa: -4.97 | Média Móvel (10 ep): -4.71 | Epsilon: 0.31
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 146/1000 | Recompensa: -5.40 | Média Móvel (10 ep): -4.82 | Epsilon: 0.31
# Episódio 147/1000 | Recompensa: -3.75 | Média Móvel (10 ep): -4.72 | Epsilon: 0.31
# Episódio 148/1000 | Recompensa: -4.11 | Média Móvel (10 ep): -4.47 | Epsilon: 0.30
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 149/1000 | Recompensa: -4.26 | Média Móvel (10 ep): -4.55 | Epsilon: 0.30
# Episódio 150/1000 | Recompensa: -5.83 | Média Móvel (10 ep): -4.65 | Epsilon: 0.30
# Episódio 151/1000 | Recompensa: -4.47 | Média Móvel (10 ep): -4.54 | Epsilon: 0.30
# Episódio 152/1000 | Recompensa: -4.55 | Média Móvel (10 ep): -4.49 | Epsilon: 0.29
# Episódio 153/1000 | Recompensa: -3.91 | Média Móvel (10 ep): -4.49 | Epsilon: 0.29
# Episódio 154/1000 | Recompensa: -4.68 | Média Móvel (10 ep): -4.59 | Epsilon: 0.29
# Episódio 155/1000 | Recompensa: -3.60 | Média Móvel (10 ep): -4.46 | Epsilon: 0.29
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 156/1000 | Recompensa: -4.67 | Média Móvel (10 ep): -4.38 | Epsilon: 0.29
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 157/1000 | Recompensa: -3.73 | Média Móvel (10 ep): -4.38 | Epsilon: 0.28
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 158/1000 | Recompensa: -4.47 | Média Móvel (10 ep): -4.42 | Epsilon: 0.28
# Episódio 159/1000 | Recompensa: -4.60 | Média Móvel (10 ep): -4.45 | Epsilon: 0.28
# Episódio 160/1000 | Recompensa: -3.47 | Média Móvel (10 ep): -4.22 | Epsilon: 0.28
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 161/1000 | Recompensa: -4.38 | Média Móvel (10 ep): -4.21 | Epsilon: 0.27
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 162/1000 | Recompensa: -4.48 | Média Móvel (10 ep): -4.20 | Epsilon: 0.27
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 163/1000 | Recompensa: -4.88 | Média Móvel (10 ep): -4.30 | Epsilon: 0.27
# Episódio 164/1000 | Recompensa: -5.11 | Média Móvel (10 ep): -4.34 | Epsilon: 0.27
# Episódio 165/1000 | Recompensa: -4.14 | Média Móvel (10 ep): -4.39 | Epsilon: 0.27
# Episódio 166/1000 | Recompensa: -5.14 | Média Móvel (10 ep): -4.44 | Epsilon: 0.26
# Episódio 167/1000 | Recompensa: -4.01 | Média Móvel (10 ep): -4.47 | Epsilon: 0.26
# Episódio 168/1000 | Recompensa: -5.69 | Média Móvel (10 ep): -4.59 | Epsilon: 0.26
# Episódio 169/1000 | Recompensa: -3.66 | Média Móvel (10 ep): -4.49 | Epsilon: 0.26
# Episódio 170/1000 | Recompensa: -5.06 | Média Móvel (10 ep): -4.65 | Epsilon: 0.26
# Episódio 171/1000 | Recompensa: -4.33 | Média Móvel (10 ep): -4.65 | Epsilon: 0.25
# Episódio 172/1000 | Recompensa: -4.24 | Média Móvel (10 ep): -4.62 | Epsilon: 0.25
# Episódio 173/1000 | Recompensa: -5.02 | Média Móvel (10 ep): -4.64 | Epsilon: 0.25
# Episódio 174/1000 | Recompensa: -3.90 | Média Móvel (10 ep): -4.52 | Epsilon: 0.25
# Episódio 175/1000 | Recompensa: -4.35 | Média Móvel (10 ep): -4.54 | Epsilon: 0.25
# Episódio 176/1000 | Recompensa: -3.93 | Média Móvel (10 ep): -4.42 | Epsilon: 0.24
# Episódio 177/1000 | Recompensa: -4.28 | Média Móvel (10 ep): -4.44 | Epsilon: 0.24
# Episódio 178/1000 | Recompensa: -4.51 | Média Móvel (10 ep): -4.33 | Epsilon: 0.24
# Episódio 179/1000 | Recompensa: -4.04 | Média Móvel (10 ep): -4.36 | Epsilon: 0.24
# Episódio 180/1000 | Recompensa: -4.25 | Média Móvel (10 ep): -4.28 | Epsilon: 0.24
# Episódio 181/1000 | Recompensa: -4.50 | Média Móvel (10 ep): -4.30 | Epsilon: 0.23
# Episódio 182/1000 | Recompensa: -3.51 | Média Móvel (10 ep): -4.23 | Epsilon: 0.23
# Episódio 183/1000 | Recompensa: -4.22 | Média Móvel (10 ep): -4.15 | Epsilon: 0.23
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 184/1000 | Recompensa: -4.24 | Média Móvel (10 ep): -4.18 | Epsilon: 0.23
# Episódio 185/1000 | Recompensa: -3.91 | Média Móvel (10 ep): -4.14 | Epsilon: 0.23
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 186/1000 | Recompensa: -4.20 | Média Móvel (10 ep): -4.16 | Epsilon: 0.22
# Episódio 187/1000 | Recompensa: -5.01 | Média Móvel (10 ep): -4.24 | Epsilon: 0.22
# Episódio 188/1000 | Recompensa: -3.58 | Média Móvel (10 ep): -4.15 | Epsilon: 0.22
# Episódio 189/1000 | Recompensa: -4.60 | Média Móvel (10 ep): -4.20 | Epsilon: 0.22
# Episódio 190/1000 | Recompensa: -4.38 | Média Móvel (10 ep): -4.22 | Epsilon: 0.22
# Episódio 191/1000 | Recompensa: -3.52 | Média Móvel (10 ep): -4.12 | Epsilon: 0.22
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 192/1000 | Recompensa: -4.41 | Média Móvel (10 ep): -4.21 | Epsilon: 0.21
# Episódio 193/1000 | Recompensa: -4.91 | Média Móvel (10 ep): -4.28 | Epsilon: 0.21
# Episódio 194/1000 | Recompensa: -3.72 | Média Móvel (10 ep): -4.22 | Epsilon: 0.21
# Episódio 195/1000 | Recompensa: -6.32 | Média Móvel (10 ep): -4.47 | Epsilon: 0.21
# Episódio 196/1000 | Recompensa: -3.95 | Média Móvel (10 ep): -4.44 | Epsilon: 0.21
# Episódio 197/1000 | Recompensa: -4.75 | Média Móvel (10 ep): -4.42 | Epsilon: 0.21
# Episódio 198/1000 | Recompensa: -3.67 | Média Móvel (10 ep): -4.42 | Epsilon: 0.20
# Episódio 199/1000 | Recompensa: -4.24 | Média Móvel (10 ep): -4.39 | Epsilon: 0.20
# Episódio 200/1000 | Recompensa: -3.51 | Média Móvel (10 ep): -4.30 | Epsilon: 0.20
# Episódio 201/1000 | Recompensa: -4.10 | Média Móvel (10 ep): -4.36 | Epsilon: 0.20
# Episódio 202/1000 | Recompensa: -4.79 | Média Móvel (10 ep): -4.40 | Epsilon: 0.20
# Episódio 203/1000 | Recompensa: -4.33 | Média Móvel (10 ep): -4.34 | Epsilon: 0.20
# Episódio 204/1000 | Recompensa: -4.41 | Média Móvel (10 ep): -4.41 | Epsilon: 0.19
# Episódio 205/1000 | Recompensa: -5.32 | Média Móvel (10 ep): -4.31 | Epsilon: 0.19
# Episódio 206/1000 | Recompensa: -4.06 | Média Móvel (10 ep): -4.32 | Epsilon: 0.19
# Episódio 207/1000 | Recompensa: -3.68 | Média Móvel (10 ep): -4.21 | Epsilon: 0.19
# Episódio 208/1000 | Recompensa: -4.69 | Média Móvel (10 ep): -4.31 | Epsilon: 0.19
# Episódio 209/1000 | Recompensa: -3.51 | Média Móvel (10 ep): -4.24 | Epsilon: 0.19
# Episódio 210/1000 | Recompensa: -4.32 | Média Móvel (10 ep): -4.32 | Epsilon: 0.19
# Episódio 211/1000 | Recompensa: -4.48 | Média Móvel (10 ep): -4.36 | Epsilon: 0.18
# Episódio 212/1000 | Recompensa: -4.23 | Média Móvel (10 ep): -4.30 | Epsilon: 0.18
# Episódio 213/1000 | Recompensa: -3.57 | Média Móvel (10 ep): -4.23 | Epsilon: 0.18
# Episódio 214/1000 | Recompensa: -4.10 | Média Móvel (10 ep): -4.20 | Epsilon: 0.18
# Episódio 215/1000 | Recompensa: -3.64 | Média Móvel (10 ep): -4.03 | Epsilon: 0.18
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 216/1000 | Recompensa: -4.65 | Média Móvel (10 ep): -4.09 | Epsilon: 0.18
# Episódio 217/1000 | Recompensa: -4.33 | Média Móvel (10 ep): -4.15 | Epsilon: 0.17
# Episódio 218/1000 | Recompensa: -4.17 | Média Móvel (10 ep): -4.10 | Epsilon: 0.17
# Episódio 219/1000 | Recompensa: -4.43 | Média Móvel (10 ep): -4.19 | Epsilon: 0.17
# Episódio 220/1000 | Recompensa: -3.59 | Média Móvel (10 ep): -4.12 | Epsilon: 0.17
# Episódio 221/1000 | Recompensa: -4.86 | Média Móvel (10 ep): -4.16 | Epsilon: 0.17
# Episódio 222/1000 | Recompensa: -3.21 | Média Móvel (10 ep): -4.05 | Epsilon: 0.17
# Episódio 223/1000 | Recompensa: -3.80 | Média Móvel (10 ep): -4.08 | Epsilon: 0.17
# Episódio 224/1000 | Recompensa: -3.66 | Média Móvel (10 ep): -4.03 | Epsilon: 0.17
# Episódio 225/1000 | Recompensa: -3.33 | Média Móvel (10 ep): -4.00 | Epsilon: 0.16
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 226/1000 | Recompensa: -4.31 | Média Móvel (10 ep): -3.97 | Epsilon: 0.16
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 227/1000 | Recompensa: -4.81 | Média Móvel (10 ep): -4.02 | Epsilon: 0.16
# Episódio 228/1000 | Recompensa: -4.18 | Média Móvel (10 ep): -4.02 | Epsilon: 0.16
# Episódio 229/1000 | Recompensa: -3.65 | Média Móvel (10 ep): -3.94 | Epsilon: 0.16
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 230/1000 | Recompensa: -4.44 | Média Móvel (10 ep): -4.02 | Epsilon: 0.16
# Episódio 231/1000 | Recompensa: -3.38 | Média Móvel (10 ep): -3.88 | Epsilon: 0.16
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 232/1000 | Recompensa: -4.06 | Média Móvel (10 ep): -3.96 | Epsilon: 0.16
# Episódio 233/1000 | Recompensa: -3.56 | Média Móvel (10 ep): -3.94 | Epsilon: 0.15
# Episódio 234/1000 | Recompensa: -3.55 | Média Móvel (10 ep): -3.93 | Epsilon: 0.15
# Episódio 235/1000 | Recompensa: -4.11 | Média Móvel (10 ep): -4.00 | Epsilon: 0.15
# Episódio 236/1000 | Recompensa: -4.03 | Média Móvel (10 ep): -3.98 | Epsilon: 0.15
# Episódio 237/1000 | Recompensa: -3.61 | Média Móvel (10 ep): -3.86 | Epsilon: 0.15
# => [Sinal Verde] Modelo Excelente Guardado!
# Episódio 238/1000 | Recompensa: -4.67 | Média Móvel (10 ep): -3.91 | Epsilon: 0.15
# Episódio 239/1000 | Recompensa: -3.75 | Média Móvel (10 ep): -3.92 | Epsilon: 0.15
# Episódio 240/1000 | Recompensa: -5.28 | Média Móvel (10 ep): -4.00 | Epsilon: 0.15
# Episódio 241/1000 | Recompensa: -4.93 | Média Móvel (10 ep): -4.15 | Epsilon: 0.14
# Episódio 242/1000 | Recompensa: -3.67 | Média Móvel (10 ep): -4.12 | Epsilon: 0.14
# Episódio 243/1000 | Recompensa: -4.21 | Média Móvel (10 ep): -4.18 | Epsilon: 0.14
# Episódio 244/1000 | Recompensa: -4.11 | Média Móvel (10 ep): -4.24 | Epsilon: 0.14
# Episódio 245/1000 | Recompensa: -3.66 | Média Móvel (10 ep): -4.19 | Epsilon: 0.14
# Episódio 246/1000 | Recompensa: -3.97 | Média Móvel (10 ep): -4.19 | Epsilon: 0.14
# Episódio 247/1000 | Recompensa: -3.69 | Média Móvel (10 ep): -4.19 | Epsilon: 0.14
# Episódio 248/1000 | Recompensa: -4.14 | Média Móvel (10 ep): -4.14 | Epsilon: 0.14
# Episódio 249/1000 | Recompensa: -3.55 | Média Móvel (10 ep): -4.12 | Epsilon: 0.14
# Episódio 250/1000 | Recompensa: -4.70 | Média Móvel (10 ep): -4.06 | Epsilon: 0.13
# Episódio 251/1000 | Recompensa: -3.96 | Média Móvel (10 ep): -3.96 | Epsilon: 0.13
# Episódio 252/1000 | Recompensa: -3.78 | Média Móvel (10 ep): -3.98 | Epsilon: 0.13
# Episódio 253/1000 | Recompensa: -3.56 | Média Móvel (10 ep): -3.91 | Epsilon: 0.13
# Episódio 254/1000 | Recompensa: -4.02 | Média Móvel (10 ep): -3.90 | Epsilon: 0.13
# Episódio 255/1000 | Recompensa: -4.37 | Média Móvel (10 ep): -3.97 | Epsilon: 0.13
# Episódio 256/1000 | Recompensa: -4.72 | Média Móvel (10 ep): -4.05 | Epsilon: 0.13
# Episódio 257/1000 | Recompensa: -4.28 | Média Móvel (10 ep): -4.11 | Epsilon: 0.13
# Episódio 258/1000 | Recompensa: -3.71 | Média Móvel (10 ep): -4.06 | Epsilon: 0.13
# Episódio 259/1000 | Recompensa: -4.18 | Média Móvel (10 ep): -4.13 | Epsilon: 0.12
# Episódio 260/1000 | Recompensa: -4.21 | Média Móvel (10 ep): -4.08 | Epsilon: 0.12
# Episódio 261/1000 | Recompensa: -3.87 | Média Móvel (10 ep): -4.07 | Epsilon: 0.12
# Episódio 262/1000 | Recompensa: -4.49 | Média Móvel (10 ep): -4.14 | Epsilon: 0.12
# Episódio 263/1000 | Recompensa: -4.22 | Média Móvel (10 ep): -4.21 | Epsilon: 0.12
# Episódio 264/1000 | Recompensa: -3.41 | Média Móvel (10 ep): -4.14 | Epsilon: 0.12
# Episódio 265/1000 | Recompensa: -3.52 | Média Móvel (10 ep): -4.06 | Epsilon: 0.12
# Episódio 266/1000 | Recompensa: -4.32 | Média Móvel (10 ep): -4.02 | Epsilon: 0.12
# Episódio 267/1000 | Recompensa: -3.33 | Média Móvel (10 ep): -3.93 | Epsilon: 0.12
# Episódio 268/1000 | Recompensa: -5.08 | Média Móvel (10 ep): -4.06 | Epsilon: 0.12
# Episódio 269/1000 | Recompensa: -4.37 | Média Móvel (10 ep): -4.08 | Epsilon: 0.12
# Episódio 270/1000 | Recompensa: -4.30 | Média Móvel (10 ep): -4.09 | Epsilon: 0.11
# Episódio 271/1000 | Recompensa: -4.01 | Média Móvel (10 ep): -4.11 | Epsilon: 0.11
# Episódio 272/1000 | Recompensa: -4.05 | Média Móvel (10 ep): -4.06 | Epsilon: 0.11
# Episódio 273/1000 | Recompensa: -4.00 | Média Móvel (10 ep): -4.04 | Epsilon: 0.11
# Episódio 274/1000 | Recompensa: -4.31 | Média Móvel (10 ep): -4.13 | Epsilon: 0.11
# Episódio 275/1000 | Recompensa: -4.24 | Média Móvel (10 ep): -4.20 | Epsilon: 0.11
# Episódio 276/1000 | Recompensa: -3.74 | Média Móvel (10 ep): -4.14 | Epsilon: 0.11
# Episódio 277/1000 | Recompensa: -4.01 | Média Móvel (10 ep): -4.21 | Epsilon: 0.11
#
# [Early Stopping] Modelo Perfeito Convergido no episódio 277.

# %%
from google.colab import files
files.download('best_traffic_dqn.pt')
